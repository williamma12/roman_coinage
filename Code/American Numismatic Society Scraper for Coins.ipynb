# %%
import pandas as pd
import requests
import io

stdout = sys.stdout
reload(sys)
sys.setdefaultencoding('utf-8')
sys.stdout = stdout

# %%
url=("http://numismatics.org/search/query.csv?q=year_num:[-27%20TO%20480]"
    + "%20AND%20department_facet:%22Roman%22&lang=en&start=")
    
batch = url + "0"
rawContent = requests.get(batch).content
data = pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
data.tail()
# Out:
#                                                   URI  \
# 995  http://numismatics.org/collection/1944.100.21593
# 996  http://numismatics.org/collection/1944.100.21594
# 997  http://numismatics.org/collection/1944.100.21595
# 998  http://numismatics.org/collection/1944.100.21596
# 999  http://numismatics.org/collection/1944.100.21597
#
#                                                  Title        RecordId  \
# 995  Bronze AE3 of Constantius II, Cyzicus, AD 337 ...  1944.100.21593
# 996  Bronze AE3 of Constantius II, Cyzicus, AD 337 ...  1944.100.21594
# 997  Bronze AE3 of Constantius II, Cyzicus, AD 337 ...  1944.100.21595
# 998  Bronze AE3 of Constantius II, Cyzicus, AD 337 ...  1944.100.21596
# 999  Bronze AE3 of Constantius II, Cyzicus, AD 337 ...  1944.100.21597
#
#           Authority                                Coin Type URI  \
# 995  Constantius II  http://numismatics.org/ocre/id/ric.8.cyz.18
# 996  Constantius II  http://numismatics.org/ocre/id/ric.8.cyz.18
# 997  Constantius II  http://numismatics.org/ocre/id/ric.8.cyz.18
# 998  Constantius II  http://numismatics.org/ocre/id/ric.8.cyz.18
# 999  Constantius II  http://numismatics.org/ocre/id/ric.8.cyz.18
#
#      Date on Object  Degree Deity Denomination Department  \
# 995             NaN     NaN   NaN          AE3      Roman
# 996             NaN     NaN   NaN          AE3      Roman
# 997             NaN     NaN   NaN          AE3      Roman
# 998             NaN     NaN   NaN          AE3      Roman
# 999             NaN     NaN   NaN          AE3      Roman
#
#              ...           Portrait            Reference  Region  \
# 995          ...           Constans  RIC VIII Cyzicus 18   Mysia
# 996          ...           Constans  RIC VIII Cyzicus 18   Mysia
# 997          ...           Constans  RIC VIII Cyzicus 18   Mysia
# 998          ...           Constans  RIC VIII Cyzicus 18   Mysia
# 999          ...           Constans  RIC VIII Cyzicus 18   Mysia
#
#            Reverse Legend                                       Reverse Type  \
# 995    GLOR-IA EXERC-ITVS  Two soldiers standing holding shield and spear...
# 996    GLOR-IA EXERC-ITVS  Two soldiers standing holding shield and spear...
# 997    GLOR-IA EXERC-ITVS  Two soldiers standing holding shield and spear...
# 998    GLOR-IA EXERC-ITVS  Two soldiers standing holding shield and spear...
# 999  GLOR-IA EXE[RC]-ITVS  Two soldiers standing holding shield and spear...
#
#      Weight     Year                                      Thumbnail_obv  \
# 995    1.60  337|340  http://numismatics.org/collectionimages/190019...
# 996    1.36  337|340  http://numismatics.org/collectionimages/190019...
# 997    1.55  337|340  http://numismatics.org/collectionimages/190019...
# 998    1.44  337|340  http://numismatics.org/collectionimages/190019...
# 999    1.96  337|340  http://numismatics.org/collectionimages/190019...
#
#                                          Thumbnail_rev  Date Record Modified
# 995  http://numismatics.org/collectionimages/190019...  2017-09-08T14:22:22Z
# 996  http://numismatics.org/collectionimages/190019...  2017-09-08T14:22:22Z
# 997  http://numismatics.org/collectionimages/190019...  2017-09-08T14:22:22Z
# 998  http://numismatics.org/collectionimages/190019...  2017-09-08T14:22:22Z
# 999  http://numismatics.org/collectionimages/190019...  2017-09-08T14:22:22Z
#
# [5 rows x 34 columns]

# %%
for i in range(1, 63):
    i *= 1000
    batch = url + str(i)
    rawContent = requests.get(batch).content
    df = pd.read_csv(io.StringIO(s.decode('utf-8')))
    data = data.append(df, ignore_index=True)

# %%
data.to_csv("../Data/ANS_Roman_Imperial_Coinage.csv")

# %%
data.tail()
# Out:
#                                                     URI  \
# 62995  http://numismatics.org/collection/1944.100.21593
# 62996  http://numismatics.org/collection/1944.100.21594
# 62997  http://numismatics.org/collection/1944.100.21595
# 62998  http://numismatics.org/collection/1944.100.21596
# 62999  http://numismatics.org/collection/1944.100.21597
#
#                                                    Title        RecordId  \
# 62995  Bronze AE3 of Constantius II, Cyzicus, AD 337 ...  1944.100.21593
# 62996  Bronze AE3 of Constantius II, Cyzicus, AD 337 ...  1944.100.21594
# 62997  Bronze AE3 of Constantius II, Cyzicus, AD 337 ...  1944.100.21595
# 62998  Bronze AE3 of Constantius II, Cyzicus, AD 337 ...  1944.100.21596
# 62999  Bronze AE3 of Constantius II, Cyzicus, AD 337 ...  1944.100.21597
#
#             Authority                                Coin Type URI  \
# 62995  Constantius II  http://numismatics.org/ocre/id/ric.8.cyz.18
# 62996  Constantius II  http://numismatics.org/ocre/id/ric.8.cyz.18
# 62997  Constantius II  http://numismatics.org/ocre/id/ric.8.cyz.18
# 62998  Constantius II  http://numismatics.org/ocre/id/ric.8.cyz.18
# 62999  Constantius II  http://numismatics.org/ocre/id/ric.8.cyz.18
#
#        Date on Object  Degree Deity Denomination Department  \
# 62995             NaN     NaN   NaN          AE3      Roman
# 62996             NaN     NaN   NaN          AE3      Roman
# 62997             NaN     NaN   NaN          AE3      Roman
# 62998             NaN     NaN   NaN          AE3      Roman
# 62999             NaN     NaN   NaN          AE3      Roman
#
#                ...           Portrait            Reference  Region  \
# 62995          ...           Constans  RIC VIII Cyzicus 18   Mysia
# 62996          ...           Constans  RIC VIII Cyzicus 18   Mysia
# 62997          ...           Constans  RIC VIII Cyzicus 18   Mysia
# 62998          ...           Constans  RIC VIII Cyzicus 18   Mysia
# 62999          ...           Constans  RIC VIII Cyzicus 18   Mysia
#
#              Reverse Legend  \
# 62995    GLOR-IA EXERC-ITVS
# 62996    GLOR-IA EXERC-ITVS
# 62997    GLOR-IA EXERC-ITVS
# 62998    GLOR-IA EXERC-ITVS
# 62999  GLOR-IA EXE[RC]-ITVS
#
#                                             Reverse Type  Weight     Year  \
# 62995  Two soldiers standing holding shield and spear...    1.60  337|340
# 62996  Two soldiers standing holding shield and spear...    1.36  337|340
# 62997  Two soldiers standing holding shield and spear...    1.55  337|340
# 62998  Two soldiers standing holding shield and spear...    1.44  337|340
# 62999  Two soldiers standing holding shield and spear...    1.96  337|340
#
#                                            Thumbnail_obv  \
# 62995  http://numismatics.org/collectionimages/190019...
# 62996  http://numismatics.org/collectionimages/190019...
# 62997  http://numismatics.org/collectionimages/190019...
# 62998  http://numismatics.org/collectionimages/190019...
# 62999  http://numismatics.org/collectionimages/190019...
#
#                                            Thumbnail_rev  Date Record Modified
# 62995  http://numismatics.org/collectionimages/190019...  2017-09-08T14:22:22Z
# 62996  http://numismatics.org/collectionimages/190019...  2017-09-08T14:22:22Z
# 62997  http://numismatics.org/collectionimages/190019...  2017-09-08T14:22:22Z
# 62998  http://numismatics.org/collectionimages/190019...  2017-09-08T14:22:22Z
# 62999  http://numismatics.org/collectionimages/190019...  2017-09-08T14:22:22Z
#
# [5 rows x 34 columns]
