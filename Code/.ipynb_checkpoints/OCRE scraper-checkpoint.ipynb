# %%
import pandas as pd
import requests
import io
import sys

stdout = sys.stdout
reload(sys)
sys.setdefaultencoding('utf-8')
sys.stdout = stdout

# %%
url=("http://numismatics.org/ocre/query.csv?start=")
    
batch = url + "0"
rawContent = requests.get(batch).content
data = pd.read_csv(io.StringIO(rawContent.decode('utf-8')))

# %%
data.tail()
# Out:
#                                                URI               Title  \
# 995   http://numismatics.org/ocre/id/ric.9.anch.64   RIC IX Antioch 64
# 996  http://numismatics.org/ocre/id/ric.9.anch.63F  RIC IX Antioch 63F
# 997  http://numismatics.org/ocre/id/ric.9.anch.63E  RIC IX Antioch 63E
# 998   http://numismatics.org/ocre/id/ric.6.tic.101  RIC VI Ticinum 101
# 999  http://numismatics.org/ocre/id/ric.9.anch.63C  RIC IX Antioch 63C
#
#            RecordId     Authority  Degree    Deity Denomination  Dynasty  \
# 995   ric.9.anch.64  Theodosius I     NaN  Victory          AE4      NaN
# 996  ric.9.anch.63F  Theodosius I     NaN      NaN          AE2      NaN
# 997  ric.9.anch.63E  Theodosius I     NaN      NaN          AE2      NaN
# 998   ric.6.tic.101     Maxentius     NaN     Roma          AE2      NaN
# 999  ric.9.anch.63C  Theodosius I     NaN      NaN          AE2      NaN
#
#      Engraver  Era          ...                    Obverse Legend  \
# 995       NaN  NaN          ...                AEL FLAC-CILLA AVG
# 996       NaN  NaN          ...              D N ARCADIVS P F AVG
# 997       NaN  NaN          ...              D N ARCADIVS P F AVG
# 998       NaN  NaN          ...             IMP MAXENTIVS P F AVG
# 999       NaN  NaN          ...           D N THEODO-SIVS P F AVG
#
#                                           Obverse Type Object Type  \
# 995  Bust of Aelia Flacilla, with elaborate head-dr...        Coin
# 996  Bust of Arcadius, rosette-diademed, draped and...        Coin
# 997  Bust of Arcadius, pearl-diademed, draped and c...        Coin
# 998  Bust of Maxentius, laureate, draped, cuirassed...        Coin
# 999  Bust of Theodosius I, pearl-diademed, draped a...        Coin
#
#            Portrait Reference Region      Reverse Legend  \
# 995  Aelia Flacilla       NaN  Syria  SALVS REI-PVBLICAE
# 996        Arcadius       NaN  Syria    VIRTVS E-XERCITI
# 997        Arcadius       NaN  Syria    VIRTVS E-XERCITI
# 998       Maxentius       NaN  Italy  CONSERV - VRB SVAE
# 999    Theodosius I       NaN  Syria    VIRTVS E-XERCITI
#
#                                           Reverse Type     Year  \
# 995  Emperor, head left, standing facing, with righ...  383|388
# 996  Emperor, standing right, holding standard and ...  383|388
# 997  Emperor, standing right, holding standard and ...  383|388
# 998  Roma, draped, seated front, head left, in hexa...  308|310
# 999  Emperor, standing right, holding standard and ...  383|388
#
#      Date Record Modified
# 995  2016-10-24T08:40:09Z
# 996  2016-10-24T08:40:08Z
# 997  2016-10-24T08:40:08Z
# 998  2016-06-24T16:27:56Z
# 999  2016-10-24T08:40:07Z
#
# [5 rows x 25 columns]

# %%
for i in range(1, 63):
    i *= 1000
    batch = url + str(i)
    rawContent = requests.get(batch).content
    df = pd.read_csv(io.StringIO(rawContent.decode('utf-8')))
    data = data.append(df, ignore_index=True)

# %%
data.to_csv("../Data/OCRE.csv")

# %%
data.tail()
# Out:
#                                                   URI                 Title  \
# 42747   http://numismatics.org/ocre/id/ric.2.hdn.1015   RIC II Hadrian 1015
# 42748   http://numismatics.org/ocre/id/ric.2.hdn.1016   RIC II Hadrian 1016
# 42749   http://numismatics.org/ocre/id/ric.2.hdn.1013   RIC II Hadrian 1013
# 42750  http://numismatics.org/ocre/id/ric.2.hdn.1011B  RIC II Hadrian 1011B
# 42751   http://numismatics.org/ocre/id/ric.2.hdn.1014   RIC II Hadrian 1014
#
#               RecordId Authority Degree  Deity Denomination Dynasty Engraver  \
# 42747   ric.2.hdn.1015   Hadrian    NaN    NaN     Quadrans     NaN      NaN
# 42748   ric.2.hdn.1016   Hadrian    NaN   Roma     Quadrans     NaN      NaN
# 42749   ric.2.hdn.1013   Hadrian    NaN  Diana     Quadrans     NaN      NaN
# 42750  ric.2.hdn.1011B   Hadrian    NaN    NaN     Quadrans     NaN      NaN
# 42751   ric.2.hdn.1014   Hadrian    NaN   Mars     Quadrans     NaN      NaN
#
#        Era          ...                            Obverse Legend  \
# 42747  NaN          ...                                       NaN
# 42748  NaN          ...                                      ROMA
# 42749  NaN          ...                                       NaN
# 42750  NaN          ...           IMP CAESAR TRAIAN HADRIANVS AVG
# 42751  NaN          ...                                       NaN
#
#                                             Obverse Type Object Type Portrait  \
# 42747                     Head of youth, laureate, right        Coin      NaN
# 42748              Bust of Roma, helmeted, draped, right        Coin  Hadrian
# 42749  Bust of Diana, draped, right, with quiver on s...        Coin  Hadrian
# 42750  Bust of Hadrian, laureate, draped, cuirassed, ...        Coin  Hadrian
# 42751                      Bust of Mars, helmeted, right        Coin      NaN
#
#       Reference    Region Reverse Legend  \
# 42747       NaN  Dalmatia     METAL DELM
# 42748       NaN       NaN      DARDANICI
# 42749       NaN  Dalmatia     METAL DELM
# 42750       NaN   Noricum        MET NOR
# 42751       NaN  Dalmatia     METAL DELM
#
#                                             Reverse Type     Year  \
# 42747                                      Stag standing  134|138
# 42748  Woman, draped, standing left, holding corn-ear...  134|138
# 42749                                 Goat standing left  134|138
# 42750                        Legend within laurel wreath  134|138
# 42751                                            Cuirass  134|138
#
#        Date Record Modified
# 42747  2017-11-28T08:46:13Z
# 42748  2017-11-28T08:46:13Z
# 42749  2017-11-28T08:46:13Z
# 42750  2017-11-28T08:46:13Z
# 42751  2017-11-28T08:46:13Z
#
# [5 rows x 25 columns]
