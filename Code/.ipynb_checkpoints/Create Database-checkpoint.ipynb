# %%
from sqlalchemy import types
from StringIO import StringIO
import sqlite3
import CleanData as cd
import numpy as np
import pandas as pd

# %% [markdown]
# # Clean Data

# %%
title = 'Roman_Imperial_Coinage'

# %% [markdown]
# ### British Museum

# %%
# Read in data and convert to appropriate types
bm_df = pd.read_csv('../Data/BM_'+title+'.csv',
                 converters={"Authority": cd.stringToList(), 'Associated names': cd.stringToList(), 
                             'Subjects': cd.stringToList(), 'Inscriptions': cd.stringToListofDicts('|', ';', ':')})
bm_df = pd.concat([bm_df, cd.cleanInscriptions(bm_df)], axis=1)
bm_df = bm_df.drop('Unnamed: 0', 1)
bm_df = bm_df.replace(np.nan, '', regex=True)
bm_df = bm_df.rename(columns = {'Culture/period':'Culture'})

# %%
# Clean data to only retain relevant information
mask = ((bm_df['Object type'] == 'coin ') & (bm_df['Date'].str.find('stC') == -1))
filtered = bm_df[mask]

lists = ['Authority', 'Subjects', 'Associated names', 'Obverse legend', 'Reverse legend']
strings = ['Museum number', 'Denomination', 'Description', 'State', 'Culture', 'Materials', 
            'Curator\'s comments', 'Bibliography', 'Object type', "Production place"]
floats = ['Weight (g)']
dates = ['Date']
redundant_notes = ['Production place', 'Denomination']
do_nothing = ['url', 'Inscriptions']
duplicate_cols = ['Authority', 'Date', 'Production place', 'Description', 'Subjects', "Curator's comments",
                  'Obverse legend', 'Reverse legend']

cleaned_bm = cd.cleanDF(filtered, lists, strings, floats, dates, redundant_notes, do_nothing, duplicate_cols)
cleaned_bm = cleaned_bm.drop('Inscriptions', 1)
cleaned_bm['Source'] = 'British Museum'
#cleaned_bm.head()

# %%
# Convert everything to strings and integers to put into SQL db
lists = ['Authority', 'Subjects', 'Associated names', 'Obverse legend', 'Reverse legend', 'Date']
for col in lists:
    cleaned_bm[col] = cleaned_bm[col].apply(cd.listToString())

columns = [u'Associated names', u'Authority', u'Bibliography', u'Culture',
       u'Curator\'s comments', u'Date', u'Denomination', u'Description',
       u'Materials', u'Museum number', u'Object type', u'Obverse legend',
       u'Production place', u'Reverse legend', u'State', u'Subjects',
       u'url', u'Source']

for col in columns:
    cleaned_bm[col] = cleaned_bm[col].apply(lambda x: x.decode('utf-8'))

cleaned_bm.columns = ['associatedNames', 'authority', 'bibliography', 'culture',
                       'curatorComment', 'date', 'denomination', 'description',
                       'materials', 'museumNumber', 'objectType', 'obverseLegend',
                       'mint', 'reverseLegend', 'state', 'subjects',
                       'weight', 'url', 'source']

cleaned_bm['startDate'] = cleaned_bm.apply(lambda row: row['date'].split(",")[0], axis=1)
cleaned_bm['endDate'] = cleaned_bm.apply(lambda row: row['date'].split(",")[1] 
                                                 if len(row['date'].split(",")) > 1 
                                                 else row['date'].split(",")[0], 
                                         axis=1)

# %%
cleaned_bm.tail()
# Out:
#            associatedNames              authority bibliography  \
# 863  Julian (the Apostate)  Julian (the Apostate)  HXN 1 161.2
# 864  Julian (the Apostate)  Julian (the Apostate)  HXN 1 160.4
# 865  Julian (the Apostate)  Julian (the Apostate)  HXN 1 159.2
# 866  Julian (the Apostate)  Julian (the Apostate)  HXN 1 158.4
# 867  Julian (the Apostate)  Julian (the Apostate)  HXN 1 163.5
#
#             culture curatorComment      date denomination  \
# 863  Roman Imperial                 360, 363            ?
# 864  Roman Imperial                 360, 363            ?
# 865  Roman Imperial                 360, 363            ?
# 866  Roman Imperial                 360, 363            ?
# 867  Roman Imperial                 360, 363            ?
#
#                                            description materials  \
# 863  Silver coin.(obverse) Head of Julian r. (rever...    silver
# 864  Silver coin.(obverse) Head of Julian r. (rever...    silver
# 865  Silver coin.(obverse) Head of Julian r. (rever...    silver
# 866  Silver coin.(obverse) Head of Julian r. (rever...    silver
# 867  Silver coin.(obverse) Head of Julian r. (rever...    silver
#
#         museumNumber   ...               obverseLegend   mint  \
# 863  1994,0401,161.2   ...        [...]C L IVLIA [...]   Lyon
# 864  1994,0401,160.4   ...    [...]C L IVLIANVS P[...]   Lyon
# 865  1994,0401,159.2   ...            D N C L IVL[...]  Trier
# 866  1994,0401,158.4   ...       [...]C L IVLIANVS AVG  Trier
# 867  1994,0401,163.5   ...                   ILLEGIBLE  Trier
#
#         reverseLegend         state                 subjects weight  \
# 863  VOTIS V MVLTIS X  Roman Empire  symbol, emperor/empress   1.07
# 864  VOTIS V MVLTIS X  Roman Empire  symbol, emperor/empress   1.20
# 865  VOTIS V MVLTIS X  Roman Empire  symbol, emperor/empress   1.11
# 866  VOTIS V MVLTIS X  Roman Empire  symbol, emperor/empress   1.32
# 867  VOTIS V MVLTIS X  Roman Empire  symbol, emperor/empress   0.96
#
#                                                    url          source  \
# 863  http://www.britishmuseum.org/research/collecti...  British Museum
# 864  http://www.britishmuseum.org/research/collecti...  British Museum
# 865  http://www.britishmuseum.org/research/collecti...  British Museum
# 866  http://www.britishmuseum.org/research/collecti...  British Museum
# 867  http://www.britishmuseum.org/research/collecti...  British Museum
#
#     startDate endDate
# 863       360     363
# 864       360     363
# 865       360     363
# 866       360     363
# 867       360     363
#
# [5 rows x 21 columns]

# %% [markdown]
# ### American Numismatic Society

# %%
ans_df = pd.read_csv('../Data/ANS_'+title+'.csv',
                    converters={"Authority": cd.stringToList('|'), 'Year': cd.stringToList('|'),
                               'Issuer': cd.stringToList('|'), 'Portrait': cd.stringToList('|'),
                               'Reference': cd.stringToList('|')})
ans_df = ans_df.replace(np.nan, '', regex=True)
ans_df['Description'] = ans_df.apply(lambda row: cd.makeDescription(
                                                                    row['Material'], 
                                                                    row['Manufacture'], 
                                                                    row['Obverse Type'], 
                                                                    row['Reverse Type']
                                                                   ), axis=1)
ans_df['DupCheck'] = ans_df.apply(lambda row: cd.makeDupCheckCol(
                                                                 row['Material'], 
                                                                 row['Denomination'], 
                                                                 row['Portrait'], 
                                                                 row['Mint'],
                                                                 row['Year']
                                                                ), axis=1)
ans_df.tail()
# Out:
#        Unnamed: 0                                          URI  \
# 62310       62310  http://numismatics.org/collection/2017.11.7
# 62311       62311  http://numismatics.org/collection/2017.11.8
# 62312       62312  http://numismatics.org/collection/2017.11.9
# 62313       62313  http://numismatics.org/collection/2015.8.48
# 62314       62314  http://numismatics.org/collection/2017.34.1
#
#                                                    Title   RecordId  \
# 62310  Billon tetradrachm, Alexandreia, AD 118 - AD 1...  2017.11.7
# 62311     Billon Tetradrachm, AD 122 - AD 123. 2017.11.8  2017.11.8
# 62312  Bronze Coin, Alexandreia, AD 164 - AD 165. 201...  2017.11.9
# 62313  Bronze AE3, Constantinople, AD 378 - AD 383. 2...  2015.8.48
# 62314  Gold Aureus of Antoninus Pius, Rome, AD 145 - ...  2017.34.1
#
#                                   Authority  \
# 62310                             [Hadrian]
# 62311                             [Hadrian]
# 62312  [Faustina II under Marcus Aurelius,]
# 62313                        [Theodosius I]
# 62314                      [Antoninus Pius]
#
#                                         Coin Type URI Date on Object Degree  \
# 62310
# 62311
# 62312
# 62313
# 62314  http://numismatics.org/ocre/id/ric.3.ant.503Aa
#
#              Deity Denomination  \
# 62310        Tyche  tetradrachm
# 62311  Athena|Nike  Tetradrachm
# 62312
# 62313                       AE3
# 62314                    Aureus
#
#                              ...                         Region  \
# 62310                        ...                          Egypt
# 62311                        ...
# 62312                        ...                          Egypt
# 62313                        ...
# 62314                        ...                          Italy
#
#       Reverse Legend                                      Reverse Type Weight  \
# 62310            L Γ  Tyche standing l. holding rudder and cornucopia.  12.73
# 62311            L ϛ         Athena standing l. holding Nikeand shield  12.71
# 62312            L E    Eagle with wings folded standing left, head r.    7.8
# 62313                                                                   2.502
# 62314      CONCORDIA                               Dove standing right   7.11
#
#              Year                                      Thumbnail_obv  \
# 62310  [118, 119]  http://numismatics.org/collectionimages/200020...
# 62311  [122, 123]  http://numismatics.org/collectionimages/200020...
# 62312  [164, 165]
# 62313  [378, 383]
# 62314  [145, 161]  http://numismatics.org/collectionimages/200020...
#
#                                            Thumbnail_rev  \
# 62310  http://numismatics.org/collectionimages/200020...
# 62311  http://numismatics.org/collectionimages/200020...
# 62312
# 62313
# 62314  http://numismatics.org/collectionimages/200020...
#
#        Date Record Modified  \
# 62310  2017-12-05T17:40:30Z
# 62311  2017-12-05T17:40:30Z
# 62312  2017-12-05T17:40:30Z
# 62313  2017-12-19T12:57:47Z
# 62314  2017-12-19T12:57:47Z
#
#                                              Description  \
# 62310   Billon. (obverse) Laureate bust r. fold of cl...
# 62311   Billon. (obverse) Laureate bust r., fold of c...
# 62312   Bronze. (obverse) Bust draped r.. (reverse) E...
# 62313                                            Bronze.
# 62314  Struck Gold. (obverse) Bust of Faustina II, dr...
#
#                                                 DupCheck
# 62310  Billon tetradrachm [''] Alexandreia ['118', '1...
# 62311            Billon Tetradrachm ['']  ['122', '123']
# 62312            Bronze  [''] Alexandreia ['164', '165']
# 62313      Bronze AE3 [''] Constantinople ['378', '383']
# 62314  Gold Aureus ['Faustina the Younger'] Rome ['14...
#
# [5 rows x 37 columns]

# %%
lists = ['Year', 'Authority', 'Issuer', 'Portrait', 'Reference']
strings = ['Deity', 'Denomination', 'Mint', 'Description', 'Obverse Legend', 'Reverse Legend']
floats = ['Weight']
dates = []
redundant_notes = []
do_nothing = ['URI', 'DupCheck']
duplicate_cols = 'DupCheck'

cleaned_ans = cd.cleanDF(ans_df, lists, strings, floats, dates, redundant_notes, do_nothing, 
                              duplicate_cols, production_place='Mint')
cleaned_ans['Source'] = 'American Numismatic Society'
cleaned_ans.drop(['DupCheck'], axis=1, inplace=True)
cleaned_ans.tail()
cleaned_ans.columns
# Out:
# Index([u'Authority', u'Deity', u'Denomination', u'Description', u'Issuer',
#        u'Mint', u'Obverse Legend', u'Portrait', u'Reference',
#        u'Reverse Legend', u'URI', u'Weight', u'Year', u'Source'],
#       dtype='object')

# %%
# Convert everything to strings and integers to put into SQL db
lists = ['Year', 'Authority', 'Issuer', 'Portrait', 'Reference']
for col in lists:
    cleaned_ans[col] = cleaned_ans[col].apply(cd.listToString())
    
cleaned_ans['StartDate'] = cleaned_ans.apply(lambda row: row['Year'].split(",")[0], axis=1)
cleaned_ans['EndDate'] = cleaned_ans.apply(lambda row: row['Year'].split(",")[1] 
                                                 if len(row['Year'].split(",")) > 1 
                                                 else row['Year'].split(",")[0], 
                                         axis=1)

columns = [u'Authority', u'Deity', u'Denomination', u'Description', u'Issuer',
       u'Mint', u'Obverse Legend', u'Portrait', u'Reference',
       u'Reverse Legend', u'URI', u'Weight', u'Year', u'Source', 'StartDate', 'EndDate']

cleaned_ans.columns = columns

for col in columns:
    cleaned_ans[col] = cleaned_ans[col].apply(lambda x: x.decode('utf-8') if type(x) is not float else x)

# %%
cleaned_ans.tail()
# Out:
#                                Authority        Deity Denomination  \
# 7826                 Saloninus as Caesar               tetradrachm
# 7827                         Claudius II        Tyche  tetradrachm
# 7828                             Hadrian         Zeus            ?
# 7829                             Hadrian  Athena|Nike  Tetradrachm
# 7830  Faustina II under Marcus Aurelius,                         ?
#
#                                             Description Issuer         Mint  \
# 7826  Billon. (obverse) Bare-headed, draped, cuirass...         Alexandreia
# 7827  Billon. (obverse) Bust laureate, draped, cuira...         Alexandreia
# 7828  Billon. (obverse) Laureate bust r. fold of clo...
# 7829  Billon. (obverse) Laureate bust r., fold of cl...
# 7830  Bronze. (obverse) Bust draped r.. (reverse) Ea...         Alexandreia
#
#                        Obverse Legend Portrait  \
# 7826     ΠΟΛΙΚΚΟΡCA OVAΛΕΡΙΑΝΟC K CEB
# 7827                ΑVTK KΛΑVΔΙΟC CEB
# 7828  AYT KAIC TPAINOC (sic) ΑΔΡΙΑΝΟC
# 7829         AYT KAI TRAI - AΔΡΙΑ CεΒ
# 7830                 ΦΑΥCTINA CεΒΑCΤΗ
#
#                                               Reference Reverse Legend  \
# 7826               BMC 2296, Cologne 3002, Dattari 5376            L ϛ
# 7827  Cologne 3048 (same rev. die, Dattari-Savio pl....            L Γ
# 7828                                 RPC 5015 (2 spec.)            L B
# 7829  Dattari-Savio, pl. 64, 7382, RPC.- cf. RPC 531...            L ϛ
# 7830  Dattari-Savio pl. 195, 3639 (this coin)., Emme...            L E
#
#                                                URI  Weight      Year  \
# 7826  http://numismatics.org/collection/2017.11.52    9.77  258, 259
# 7827  http://numismatics.org/collection/2017.11.53    9.69  269, 270
# 7828   http://numismatics.org/collection/2017.11.6   13.74  117, 118
# 7829   http://numismatics.org/collection/2017.11.8   12.71  122, 123
# 7830   http://numismatics.org/collection/2017.11.9    7.80  164, 165
#
#                            Source StartDate EndDate
# 7826  American Numismatic Society       258     259
# 7827  American Numismatic Society       269     270
# 7828  American Numismatic Society       117     118
# 7829  American Numismatic Society       122     123
# 7830  American Numismatic Society       164     165

# %% [markdown]
# # Store Data

# %%
cnx = sqlite3.connect('../Data/'+title+'.sqlite')
cur = cnx.cursor()

# %%
cur.execute('''CREATE TABLE britishMuseum(associatedNames TEXT, authority TEXT, bibliography TEXT, culture TEXT,
                    curatorComment TEXT, dates TEXT, denomination TEXT, 
                    description TEXT, materials TEXT, museumNumber TEXT, objectType TEXT, obverseLegend TEXT,
                    mint TEXT, reverseLegend TEXT, state TEXT, subjects TEXT, weight INT,
                    url TEXT, source TEXT, startDate INT, endDate INT)''')

# %%
cur.executemany("""INSERT INTO britishMuseum (associatedNames, authority, bibliography, culture,
                        curatorComment, dates, denomination, description,
                        materials, museumNumber, objectType, obverseLegend,
                        mint, reverseLegend, state, subjects, weight,
                        url, source, startDate, endDate) VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", 
                list(cleaned_bm.to_records(index=False)))

# %%
cur.execute('''CREATE TABLE americanNumismaticSociety(authority TEXT, deity TEXT, denomination TEXT, description TEXT, 
                       issuer TEXT, mint TEXT, obverseLegend TEXT, portrait TEXT, reference TEXT, reverseLegend TEXT, 
                       url TEXT, weight INT, dates TEXT, source TEXT, startDate INT, endDate INT)''')

# %%
cur.executemany("""INSERT INTO americanNumismaticSociety (authority, deity, denomination, description, 
                       issuer, mint, obverseLegend, portrait, reference, reverseLegend, url, weight, dates, 
                       source, startDate, endDate) VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", 
                list(cleaned_ans.to_records(index=False)))

# %%
cnx.commit()
