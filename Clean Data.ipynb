# %%
import pandas as pd
import numpy as np
import doctest
import re

# %%
df = pd.read_csv('AugustusCoins_44BC-14AD.csv')
df = df.drop('Unnamed: 0', 1)
df = df.replace(np.nan, '', regex=True)
df.head(5)
# Out:
#                                   Associated names  \
# 0                 Portrait of: Augustus (Octavian)
# 1                 Portrait of: Augustus (Octavian)
# 2  Named in inscription & portrayed: Julius Caesar
# 3
# 4           Representation of: Augustus (Octavian)
#
#                          Authority             Bibliography    Culture/period  \
# 0      Ruler:  Augustus (Octavian)                RPC1 1801
# 1      Ruler:  Augustus (Octavian)                RPC1 5476  Roman Provincial
# 2      Ruler:  Augustus (Octavian)                RPC1 2007  Roman Provincial
# 3  Ruler:  Augustus (Octavian) (?)                                      Greek
# 4                                   Walker & Higgs 2001 308  Roman Republican
#
#                                   Curator's comments       Date Denomination  \
# 0                                                       27BC-14
# 1                                                       27BC-14
# 2                                                       31BC-14
# 3                                                       27BC-14
# 4  The portrait probably dates from the later 30s...  44BC-40BC
#
#                                          Description  \
# 0          Bronze coin.(obverse) Head of Augustus r.
# 1          Bronze coin.(obverse) Head of Augustus r.
# 2   Alloy coin.(obverse) Diademed head of Caesar, r.
# 3                                        Alloy coin.
# 4  Seal of glass paste imitating sard: with a bus...
#
#                                         Inscriptions Materials  Museum number  \
# 0                                                 []    bronze    1997,1206.1
# 1                                                 []    bronze    2001,0335.3
# 2  [{u'Inscription Position': u'reverse', u'Inscr...     alloy         G.1200
# 3                                                        alloy    1905,1111.1
# 4                                                        glass  1923,0401.928
#
#   Object type       Production place         State         Subjects  \
# 0        coin     Minted in: Odessus  Roman Empire           symbol
# 1        coin                         Roman Empire           symbol
# 2        coin      Minted in: Apamea  Roman Empire  emperor/empress
# 3        coin  Minted in: Cremna (?)
# 4        seal
#
#   Weight (g)                                                url
# 0       7.45  http://www.britishmuseum.org/research/collecti...
# 1       2.27  http://www.britishmuseum.org/research/collecti...
# 2       8.36  http://www.britishmuseum.org/research/collecti...
# 3       1.49  http://www.britishmuseum.org/research/collecti...
# 4             http://www.britishmuseum.org/research/collecti...

# %% [markdown]
# ## Clean Data

# %%
def cleanString(string):
    '''
    Parameters
    ----------
    string: str
        String that needs to be cleaned
    
    Returns
    -------
    Removes the descriptor and returns the (assumed) description
    
    Doctests
    --------
    >>> cleanString('Named in inscription & portrayed: Julius Caesar (probably)')
    'Julius Caesar'
    >>> cleanString('Ruler: Augustus (Octavian) (?)')
    'Augustus (Octavian)'
    >>> cleanString('dupondius (?)')
    'dupondius'
    '''
    result = string.replace('(?)', "").replace('(probably)', "")
    if ':' in result:
        result = [s for s in result.split(':')][1]
    return result.strip()

doctest.testmod()
#cleanString('Ruler: Augustus (Octavian) (?)')
#cleanString('dupondius (?)')
# Out:
# TestResults(failed=0, attempted=6)

# %%
def dateRange(date):
    '''
    Parameter
    ---------
    date: str
        Date range given as a string
    
    Returns
    -------
    Returns list of the date range
    
    Doctests
    --------
    >>> dateRange('27BC-14 (?)')
    [-27, 14]
    >>> dateRange('44BC (cira) -40BC')
    [-44, -40]
    >>> dateRange('4-14')
    [4, 14]
    
    TODO
    ----
    * Handle specific notes of dates
    '''
    dates = date.split('-')
    result = []
    
    for year in dates:
        certain = True
        bc = 'BC' in year
        try:
            year = int(re.sub('[^\d]', '', year))
        except:
            print(year)
            break
        if bc:
            year = 0 - year
        result.append(year)
        
    return result
        
doctest.testmod()
#dateRange('27BC-14 (?)')
# Out:
# TestResults(failed=0, attempted=6)

# %%
def float_conversion(x):
    '''
    Parameter
    ---------
    x: str
        Input value
    
    Return
    ------
    Returns the float or 0 if empty string
    '''
    try:
        x = float(x)
    except:
        x = 0
    return x

# %%
mask = (df['Object type'] == 'coin') & (df['Date'].str.find('stC') == -1)
cleaned = df[mask]
weights = cleaned.pop('Weight (g)').replace(np.nan, -1)
dates = cleaned.pop('Date')

cleaned = cleaned.applymap(cleanString)
cleaned['Weight (g)'] = weights.map(float_conversion)
cleaned['Date'] = dates.map(dateRange)
cleaned.head()
# Out:
#       Associated names            Authority Bibliography    Culture/period  \
# 0  Augustus (Octavian)  Augustus (Octavian)    RPC1 1801
# 1  Augustus (Octavian)  Augustus (Octavian)    RPC1 5476  Roman Provincial
# 2        Julius Caesar  Augustus (Octavian)    RPC1 2007  Roman Provincial
# 3                       Augustus (Octavian)                          Greek
# 6                       Augustus (Octavian)                          Greek
#
#   Curator's comments Denomination  \
# 0
# 1
# 2
# 3
# 6
#
#                                         Description  \
# 0         Bronze coin.(obverse) Head of Augustus r.
# 1         Bronze coin.(obverse) Head of Augustus r.
# 2  Alloy coin.(obverse) Diademed head of Caesar, r.
# 3                                       Alloy coin.
# 6                                       Alloy coin.
#
#                       Inscriptions Materials Museum number Object type  \
# 0                               []    bronze   1997,1206.1        coin
# 1                               []    bronze   2001,0335.3        coin
# 2  u'reverse', u'Inscription Type'     alloy        G.1200        coin
# 3                                      alloy   1905,1111.1        coin
# 6                                      alloy  1936,0220.13        coin
#
#   Production place         State         Subjects  \
# 0          Odessus  Roman Empire           symbol
# 1                   Roman Empire           symbol
# 2           Apamea  Roman Empire  emperor/empress
# 3           Cremna
# 6         Tyndaris
#
#                                                  url  Weight (g)       Date
# 0  //www.britishmuseum.org/research/collection_on...        7.45  [-27, 14]
# 1  //www.britishmuseum.org/research/collection_on...        2.27  [-27, 14]
# 2  //www.britishmuseum.org/research/collection_on...        8.36  [-31, 14]
# 3  //www.britishmuseum.org/research/collection_on...        1.49  [-27, 14]
# 6  //www.britishmuseum.org/research/collection_on...        7.41  [-27, 14]

# %%
cleaned[['Bibliography', 'url']].to_csv('test.csv')
